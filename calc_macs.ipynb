# %%
from src.utils.macs import calc_macs, calc_LB
from imgclsmob.pytorch.pytorchcv.model_provider import get_model as ptcv_get_model



import torch
import torch.nn as nn

# %%
model = ptcv_get_model('shufflenet_g3_wd4')
# model.features.final_pool = nn.AdaptiveAvgPool2d(1)
# model.output.conv2 = nn.Conv2d(1024, 9, 1, 1)
# model.output = nn.Linear(128, 9)
model
# calc_LB(1700000, 0.66)
# Out:
# [[60, 60, 60, 60], [120, 120, 120, 120, 120, 120, 120, 120], [240, 240, 240, 240]]
# ShuffleNet(
#   (features): Sequential(
#     (init_block): ShuffleInitBlock(
#       (conv): Conv2d(3, 6, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (stage1): Sequential(
#       (unit1): ShuffleUnit(
#         (compress_conv1): Conv2d(6, 15, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (compress_bn1): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (c_shuffle): ChannelShuffle(groups=3)
#         (dw_conv2): Conv2d(15, 15, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=15, bias=False)
#         (dw_bn2): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
calc_macs(model, (3, 64, 64))
# Out:
# 1782537.0

# %%
model = ptcv_get_model('mobilenetv3_small_w7d20')
model.features.final_pool = nn.AdaptiveAvgPool2d(1)
model.output.conv2 = nn.Conv2d(1280, 9, 1, 1)
# model.output = nn.Linear(128, 9)
model
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (init_block): ConvBlock(
#       (conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): HSwish()
#     )
#     (stage1): Sequential(
#       (unit1): MobileNetV3Unit(
#         (conv1): ConvBlock(
#           (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#           (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (se): SEBlock(
#           (pool): AdaptiveAvgPool2d(output_size=1)
#           (conv1): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1))
#           (activ): ReLU(inplace=True)
#           (conv2): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): HSigmoid()
#         )
#         (conv2): ConvBlock(
# ...

# %%
calc_macs(model, (3, 224, 224))
# Out:
# ...
# 13408713.0

# %%
calc_macs(model, (3, 224, 224))
# Out:
# 657124368.0

# %%
model = timm.create_model('eca_nfnet_l0')
print(calc_macs(model, (3, 224, 224)))
model.head.fc = nn.Linear(2304, 9, bias=True)
print(calc_macs(model, (80, 80)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1729003d5cbe> in <module>
# ----> 1 model = timm.create_model('eca_nfnet_l0')
#       2 print(calc_macs(model, (3, 224, 224)))
#       3 model.head.fc = nn.Linear(2304, 9, bias=True)
#       4 print(calc_macs(model, (80, 80)))
#
# NameError: name 'timm' is not defined

# %%
import torch.nn as nn
model = ptcv_get_model('shufflenetv2_wd2')
model.features.final_pool = nn.AdaptiveAvgPool2d(1)
# print(calc_macs(model, (3, 80, 80)))
# model.output.conv2 = nn.Conv2d(1024, 9, kernel_size=(1,1), stride=(1,1))

# # model.features.final_pool = nn.AvgPool2d(kernel_size=1, stride=1, padding=0)
# #model.features.final_pool = nn.AdaptiveAvgPool2d(1)
model.output = nn.Linear(1024, 9)
model
# Out:
# ShuffleNetV2(
#   (features): Sequential(
#     (init_block): ShuffleInitBlock(
#       (conv): ConvBlock(
#         (conv): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activ): ReLU(inplace=True)
#       )
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     )
#     (stage1): Sequential(
#       (unit1): ShuffleUnit(
#         (compress_conv1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (compress_bn1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dw_conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (dw_bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (expand_conv3): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
calc_macs(model, (3, 224, 224))
# Out:
# ...
# 41860713.0

# %%
params = {'alpha':0.5, 'temperature': 20}
params.alpha
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-43875b4cc84e> in <module>
#       1 params = {'alpha':0.5, 'temperature': 20}
# ----> 2 params.alpha
#
# AttributeError: 'dict' object has no attribute 'alpha'

# %%
m = nn.AdaptiveAvgPool2d(1)
input = torch.randn(1, 64, 10, 9)
output = m(input)
output.shape
# Out:
# torch.Size([1, 64, 1, 1])
